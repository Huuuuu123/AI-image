# %%
from datasets import load_dataset
data_files = {"train": "data-0000.zip", }
dataset = load_dataset("animelover/genshin-impact-images")
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 from datasets import load_dataset
#       2 data_files = {"train": "data-0000.zip", }
# ----> 3 dataset = load_dataset("animelover/genshin-impact-images")
#
# File D:\Anaconda\envs\ldm\lib\site-packages\datasets\load.py:1758, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, ignore_verifications, keep_in_memory, save_infos, revision, use_auth_token, task, streaming, num_proc, **config_kwargs)
#    1755 try_from_hf_gcs = path not in _PACKAGED_DATASETS_MODULES
#    1757 # Download and prepare data
# -> 1758 builder_instance.download_and_prepare(
#    1759     download_config=download_config,
#    1760     download_mode=download_mode,
#    1761     ignore_verifications=ignore_verifications,
#    1762     try_from_hf_gcs=try_from_hf_gcs,
# ...

# %%
from datasets import load_dataset
# dataset = load_dataset("data-0000",split="train")
dataset = load_dataset("animelover/danbooru2022", split="train",data_files="data/data-0000.zip")
# Out:
# ...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[11], line 3
#       1 from datasets import load_dataset
#       2 # dataset = load_dataset("data-0000",split="train")
# ----> 3 dataset = load_dataset("animelover/danbooru2022", split="train",data_files="data/data-0000.zip")
#
# File D:\Anaconda\envs\ldm\lib\site-packages\datasets\load.py:1735, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, ignore_verifications, keep_in_memory, save_infos, revision, use_auth_token, task, streaming, num_proc, **config_kwargs)
#    1732 ignore_verifications = ignore_verifications or save_infos
#    1734 # Create a dataset builder
# -> 1735 builder_instance = load_dataset_builder(
#    1736     path=path,
#    1737     name=name,
#    1738     data_dir=data_dir,
#    1739     data_files=data_files,
# ...

# %%
dataset['image']
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 dataset['image']
#
# File D:\Anaconda\envs\ldm\lib\site-packages\datasets\arrow_dataset.py:2590, in Dataset.__getitem__(self, key)
#    2588 def __getitem__(self, key):  # noqa: F811
#    2589     """Can be used to index columns (by string names) or rows (by integer index or iterable of indices or bools)."""
# -> 2590     return self._getitem(
#    2591         key,
#    2592     )
#
# File D:\Anaconda\envs\ldm\lib\site-packages\datasets\arrow_dataset.py:2575, in Dataset._getitem(self, key, **kwargs)
#    2573 formatter = get_formatter(format_type, features=self.features, **format_kwargs)
#    2574 pa_subtable = query_table(self._data, key, indices=self._indices if self._indices is not None else None)
# -> 2575 formatted_output = format_table(
# ...
